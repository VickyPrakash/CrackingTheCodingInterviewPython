# %%
class node:
    def __init__(self, dataval = None):
        self.dataval = dataval;
        self.nextval = None;

class SLinkedList:
    def __init__(self):
        self.headval = None;
    
    def printList(self):
        n = self.headval;
        print(n.dataval);
        n = n.nextval;
        while(n.nextval != None):
            print(n.dataval);
            n = n.nextval;
        print(n.dataval);
    
    def insertNode(self, dataval):
        newNode = node(dataval);
        n = self.headval;
        while(n.nextval != None):
            n = n.nextval;
        n.nextval = newNode;
    
    def deleteNode(self, dataval):
        if(self.headval == None):
            print("No element in the list to be deleted.");
        elif(self.headval.dataval == dataval):
            while(self.headval.dataval == dataval):
                self.headval = self.headval.nextval;
                print("Data was in the head Node. It has been deleted");
        #else:
        n = self.headval.nextval;
        prev = self.headval;

        while(n.nextval != None):
            if(n.dataval == dataval):
                prev.nextval = n.nextval;
                n = prev.nextval
            else:
                prev = prev.nextval;
                n = n.nextval;
        if(n.dataval == dataval):
            prev.nextval = None;
            
    def removeDupsFollow(self):
        n = self.headval;
        #prev = self.headval;
        n = n.nextval;
        while(n.nextval != None):
            m = n.nextval;
            #m = m.nextval;
            prev = n;
            while(m.nextval != None):
                if(n.dataval == m.dataval):
                    prev.nextval = m.nextval;
                    m = m.nextval;
                else:
                    prev = prev.nextval;
                    m = m.nextval;
            if(n.dataval == m.dataval):
                prev.nextval = None;
            n = n.nextval;
            
    def removeDups(self):
        array = [];
        n = self.headval;
        array.append(n.dataval);
        n = n.nextval;
        prev = self.headval;
        while(n.nextval != None):
            flag = 0;
            for i in range(len(array)):
                if(n.dataval == array[i]):
                    flag = 1;
                    break;
            if (flag == 0):
                array.append(n.dataval);
                prev = prev.nextval;
                n = n.nextval;
            else:
                prev.nextval = n.nextval;
                n = n.nextval;
        
        for i in range(len(array)):
            if (n.dataval == array[i]):
                prev.nextval = None;
                
    def Ktolast(self, k):
        n = self.headval;
        length = 0;
        n = n.nextval;
        length += 1;
        while(n.nextval != None):
            length += 1;
            n = n.nextval;
        length += 1;  
        print(length);
        n = self.headval;
        n = n.nextval;
        nodek = length - k - 1;
        while(n.nextval != None):
            if(nodek == 0):
                print(n.dataval);
                break;
            else:
                nodek -= 1;
                n = n.nextval;
    def DelMidNode(self, node1):
        n = self.headval;
        prev = self.headval;
        n = n.nextval;
        while(n.nextval != None):
            if(n == node1):
                prev.nextval = n.nextval;
                n = n.nextval;
                break;
            else:
                prev = prev.nextval;
                n = n.nextval;
                
    
            

e1 = node("Mon");
e2 = node("Tue");
e3 = node("Wed");
e4 = node("Thurs");
e5 = node("Fri");
list1 = SLinkedList();
list1.headval = e1;
e1.nextval = e2;
e2.nextval = e3;
e3.nextval = e4;
e4.nextval = e5;
list1.insertNode("Fri");
list1.insertNode("Mon");
list1.insertNode("Fri");
list1.printList();
print("Wait");
#list1.deleteNode("Mon");
print("Remove Duplicate");
#list1.removeDups();
list1.removeDupsFollow();
list1.printList();
print("K to last");
list1.Ktolast(2);
print("Delete Middle Node");
list1.DelMidNode(e3);
list1.printList();
# Out:
# Mon
# Tue
# Wed
# Thurs
# Fri
# Fri
# Mon
# Fri
# Wait
# Remove Duplicate
# Mon
# Tue
# Wed
# Thurs
# Fri
# Mon
# K to last
# 6
# Fri
# Delete Middle Node
# Mon
# Tue
# Thurs
# Fri
# Mon

# %%
import math;

class digit:
    def __init__(self, dataval = None):
        self.dataval = dataval;
        self.nextval = None;

class DigitLinkedList:
    def __init__(self):
        self.headval = None;
    
    def printList(self):
        n = self.headval;
        print(n.dataval);
        n = n.nextval;
        while(n.nextval != None):
            print(n.dataval);
            n = n.nextval;
        print(n.dataval);
    
    def insertNode(self, dataval):
        newNode = digit(dataval);
        n = self.headval;
        while(n.nextval != None):
            n = n.nextval;
        n.nextval = newNode;
        
    def partition(self, value):
        n = self.headval;
        prev = self.headval;
        n = n.nextval;
        while(n != None):
            if(n.dataval < value):
                new = digit(n.dataval);
                new.nextval = self.headval;
                self.headval = new;
                
                prev.nextval = n.nextval;
                n = n.nextval;
            else:
                n = n.nextval;
                prev = prev.nextval;
                
def SumUp(num1, num2):
    number1 = 0
    n = num1.headval;
    number1 = n.dataval;
    n = n.nextval;
    k = 10;
    while(n.nextval != None):
        number1 = number1 + (k * n.dataval);
        k = k * 10;
        n = n.nextval;
    number1 = number1 + (k * n.dataval);

    number2 = 0;
    n = num2.headval;
    number2 = n.dataval;
    n = n.nextval;
    k = 10;
    while(n.nextval != None):
        number2 = number2 + (k * n.dataval);
        k = k * 10;
        n = n.nextval;
    number2 = number2 + (k * n.dataval);
    print(number1);
    print(number2);
    number3 = number1 + number2;
    num3 = DigitLinkedList();
    n = number3 % 10;
    
    e1 = digit(n);
    number3 = math.floor(number3 / 10);
    print("Number", number3);
    num3.headval = e1;
    while(number3 > 0):
        num3.insertNode(number3 % 10);
        number3 = math.floor(number3 / 10);
    
    num3.printList();

def Palindrome(list1):
    array = [];
    n = list1.headval;
    array.append(n.dataval);
    n = n.nextval;
    while(n.nextval != None):
        array.append(n.dataval);
        n = n.nextval;
    array.append(n.dataval);
    n = list1.headval;
    flag = 0;
    if(n.dataval != array[len(array) - 1]):
        print("test");
        print(n.dataval);
        print(array[len(array) - 1]);
        flag = 1;
    for i in range(math.floor((len(array)/2)) + 1):
        if(n.dataval != array[len(array) - i-1]):
            flag = 1;
            break;
        n = n.nextval;
    if(flag == 1):
        print("Not Palindrome");
    else:
        print("Palindrome");

def Intersection(list1, list2):
    n = list1.headval;
    m = list2.headval;
    if(n == m):
        print("The intersecting node has value: ", n.dataval);
        return;
    m = m.nextval;
    while(m.nextval != None):
        if(n == m):
            print("The intersecting node has value: ", n.dataval);
            return;
        m = m.nextval;
    if(n == m):
        print("The intersecting node has value: ", n.dataval);
        return;
    n = n.nextval;
    #m = m.nextval;
    while(n.nextval != None):
        m = list2.headval;
        if(n == m):
            print("The intersecting node has value: ", n.dataval);
            return;
        m = m.nextval;
        while(m.nextval != None):
            if(n == m):
                print("The intersecting node has value: ", n.dataval);
                return;
            m = m.nextval;
        if(n == m):
            print("The intersecting node has value: ", n.dataval);
            return;
        n = n.nextval;
        
    m = list2.headval;
    if(n == m):
            print("The intersecting node has value: ", n.dataval);
            return;
    while(m.nextval != None):
        if(n == m):
            print("The intersecting node has value: ", n.dataval);
            return;
        m = m.nextval;
    if(n == m):
        print("The intersecting node has value: ", n.dataval);
        return;
def LoopDetection(list1):
    slow = list1.headval;
    fast = list1.headval;
    #slow = slow.nextval;
    #fast = fast.nextval.nextval;
    #if(slow == fast):
        
    while(fast != None and fast.nextval != None):
        
        slow = slow.nextval;
        fast = fast.nextval.nextval;
        if(slow == fast):
            break;
    slow = list1.headval;
    if(fast == slow):
        print("The loop begining node is: ", slow.dataval);
        return;
    
    while(fast != slow):
        slow = slow.nextval;
        fast = fast.nextval;
    print("The loop begining node is: ", fast.dataval);
    
    
    
c1 = digit(96);
c2 = digit(65);
c3 = digit(10);
c4 = digit(56);
c5 = digit(9);
c6 = digit(100);
c7 = digit(10);
list2 = DigitLinkedList();
list2.headval = c1;
c1.nextval = c2;
c2.nextval = c3;
c3.nextval = c4;
c4.nextval = c5;
c5.nextval = c6;
c6.nextval = c7;
list2.printList();
print("After Partition");
list2.partition(60);
list2.printList();
print("Numbers")
val1 = digit(6);
val2 = digit(1);
val3 = digit(7);
new1 = DigitLinkedList();
new1.headval = val1;
val1.nextval = val2;
val2.nextval = val3;
new1.printList();

val11 = digit(9);
val21 = digit(3);
val31 = digit(8);
val41 = digit(10);
val51 = digit(11);

new2 = DigitLinkedList();
new2.headval = val11;
val11.nextval = val21;
val21.nextval = val3;
new2.printList();

SumUp(new1, new2);
new3 = DigitLinkedList();
new3.headval = digit(9);
new3.insertNode(8);
new3.insertNode(7);
new3.insertNode(8);
new3.insertNode(9);
new3.printList();
Palindrome(new3);
Intersection(new1, new2);
new4 = DigitLinkedList();
new4.headval = val11;
val11.nextval = val21;
val21.nextval = val31;
val31.nextval = val41;
val41.nextval = val51;
val51.nextval = val31;
print("Loop detection");
LoopDetection(new4);
# Out:
# 96
# 65
# 10
# 56
# 9
# 100
# 10
# After Partition
# 10
# 9
# 56
# 10
# 96
# 65
# 100
# Numbers
# 6
# 1
# 7
# 9
# 3
# 7
# 716
# 739
# Number 145
# 5
# 5
# 4
# 1
# 9
# 8
# 7
# 8
# 9
# Palindrome
# The intersecting node has value:  7
# Loop detection
# The loop begining node is:  8

# %%
class number:
    def __init__(self):
        self.headval = None;
    
    def SumUp(self, num1, num2):
        number1 = 0
        n = num1.headval;
        number1 = n.dataval;
        n = n.nextval;
        k = 10;
        while(n.nextval != None):
            number1 = number1 + (k * n.dataval);
            k = k * 10;
            n = n.nextval;
        number1 = number1 + (k * n.dataval);
        
        number2 = 0;
        n = num2.headval;
        number2 = n.dataval;
        n = n.nextval;
        k = 10;
        while(n.nextval != None):
            number2 = number2 + (k * n.dataval);
            k = k * 10;
            n = n.nextval;
        number2 = number2 + (k * n.dataval);
        print(number1);
        print(number2);
# Out:
# 6
# 1
# 7
# 9
# 3
# 8
